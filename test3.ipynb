# %%
import pandas as pd
import numpy as np

import xgboost
import scipy.stats as stats

import lightgbm as lgb


from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


from matplotlib import pyplot as plt

from datetime import datetime
import ephem

# %%
SEED = 42

# %%
# Define the function to return the SMAPE value
def smape(actual, predicted) -> float:
  
    # Convert actual and predicted to numpy
    # array data type if not already
    if not all([isinstance(actual, np.ndarray), 
                isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual),
        np.array(predicted)
  
    return round(
        np.mean(
            np.abs(predicted - actual) / 
            ((np.abs(predicted) + np.abs(actual))/2)
        )*100, 6
    )

# %%
df = pd.read_csv('new_train.csv')
df.head()
# Out:
#               waktu_setempat   id_jalan  id_titik_mulai  id_titik_akhir  \
# 0  2020-02-01 01:00:00+00:00  691007296        21390008      1425033102
# 1  2020-02-01 01:00:00+00:00   47010584      1677092762       579493410
# 2  2020-02-01 01:00:00+00:00   22932408        26486694      1930267566
# 3  2020-02-01 01:00:00+00:00  142479648      1111592522      3775231113
# 4  2020-02-01 01:00:00+00:00    8504977      5940503398      5940503394
#
#    rerata_kecepatan  lanes  lanes:forward  lit maxspeed  mulai_lat  mulai_lon  \
# 0            29.126    3.0            2.0  yes   30 mph  51.434928  -0.161176
# 1            46.576    NaN            NaN  yes   30 mph  51.623990  -0.176398
# 2            36.587    NaN            NaN  yes   20 mph  51.452530  -0.152437
# 3            34.063    3.0            1.0  yes   20 mph  51.465851  -0.154188
# 4            38.336    2.0            NaN  yes   30 mph  51.530289  -0.228343
#
#    akhir_lat  akhir_lon  distance
# 0  51.434975  -0.161090    0.0000
# 1  51.623811  -0.176424    0.0106
# 2  51.452749  -0.151896    0.0280
# 3  51.465654  -0.155334    0.0503
# 4  51.530197  -0.227949    0.0000

# %%
def prepare_data(df):
    df = df.drop(['lanes', 'lanes:forward', 'lit'], axis=1)

    unique_maxspeed = df['maxspeed'].unique()
    max_speed = []
    for data in tqdm(df['maxspeed'].to_numpy(), desc='Convert to kph'):
        if data == '30 mph':
            max_speed.append(48.2803)
        elif data == '20 mph':
            max_speed.append(32.1869)

    df['maxspeed'] = max_speed
    
    is_weekend = []
    is_night = []
    is_rush_hour = []
    date = []
    hour = []

    uk_observer = ephem.Observer()
    uk_observer.lat = '51.5074'  # Latitude of London
    uk_observer.lon = '-0.1278'  # Longitude of London


    for data in tqdm(df['waktu_setempat'].to_numpy(), desc='time categorization'):
        datetime_obj = datetime.strptime(data, '%Y-%m-%d %H:%M:%S%z')
        day_of_week = datetime_obj.weekday()
        if day_of_week >= 5:
            is_weekend.append(1)
        else:
            is_weekend.append(0)
        date_component = datetime_obj.strftime('%Y-%m-%d')
        hour_component = datetime_obj.strftime('%H')
        date.append(date_component)
        hour.append(int(hour_component))
        # Set the observer's date and time to the input UTC time
        uk_observer.date = datetime_obj

        # Calculate sunrise and sunset times
        sunrise = uk_observer.previous_rising(ephem.Sun())
        sunset = uk_observer.next_setting(ephem.Sun())
        if sunrise < uk_observer.date < sunset:
            is_night.append(0)
        else:
            is_night.append(1)
        
        # Define the time ranges
        morning_rush_hour_start = datetime.strptime('10:00:00', '%H:%M:%S').time()
        morning_rush_hour_end = datetime.strptime('16:00:00', '%H:%M:%S').time()

        night_rush_hour_start = datetime.strptime('20:00:00', '%H:%M:%S').time()
        night_rush_hour_end = datetime.strptime('23:59:59', '%H:%M:%S').time()

        night_rush_hour_start_2 = datetime.strptime('00:00:00', '%H:%M:%S').time()
        night_rush_hour_end_2 = datetime.strptime('06:00:00', '%H:%M:%S').time()

        # Extract the time component from the input datetime object
        input_time = datetime_obj.time()

        # Check if the time falls within the desired ranges
        if morning_rush_hour_start <= input_time <= morning_rush_hour_end or (night_rush_hour_start <= input_time <= night_rush_hour_end) or (night_rush_hour_start_2 <= input_time <= night_rush_hour_end_2):
            is_rush_hour.append(1)
        else:
            is_rush_hour.append(0)

    df['is_weekend'] = is_weekend
    df['hour'] = hour
    df['date'] = date
    df['is_night'] = is_night
    df['is_rush_hour'] = is_rush_hour
    df = df.drop(['waktu_setempat'], axis=1)
    
    return df

# %%
df = prepare_data(df)
df.head()
# Out:
# Convert to kph: 100%|██████████| 398648/398648 [00:00<00:00, 5107588.76it/s]
# time categorization: 100%|██████████| 398648/398648 [00:26<00:00, 14858.32it/s]
#     id_jalan  id_titik_mulai  id_titik_akhir  rerata_kecepatan  maxspeed  \
# 0  691007296        21390008      1425033102            29.126   48.2803
# 1   47010584      1677092762       579493410            46.576   48.2803
# 2   22932408        26486694      1930267566            36.587   32.1869
# 3  142479648      1111592522      3775231113            34.063   32.1869
# 4    8504977      5940503398      5940503394            38.336   48.2803
#
#    mulai_lat  mulai_lon  akhir_lat  akhir_lon  distance  is_weekend  hour  \
# 0  51.434928  -0.161176  51.434975  -0.161090    0.0000           1     1
# 1  51.623990  -0.176398  51.623811  -0.176424    0.0106           1     1
# 2  51.452530  -0.152437  51.452749  -0.151896    0.0280           1     1
# 3  51.465851  -0.154188  51.465654  -0.155334    0.0503           1     1
# 4  51.530289  -0.228343  51.530197  -0.227949    0.0000           1     1
#
#          date  is_night  is_rush_hour
# 0  2020-02-01         0             1
# 1  2020-02-01         0             1
# 2  2020-02-01         0             1
# 3  2020-02-01         0             1
# 4  2020-02-01         0             1

# %%
X = df.drop(['id_jalan', 'id_titik_mulai', 'id_titik_akhir', 'date', 'rerata_kecepatan'], axis=1)
y = df['rerata_kecepatan'].to_numpy()
# max_speed = y.max() * 1.2
# y = y / max_speed

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED, shuffle=True)

# %%
model = xgboost.XGBRegressor(n_jobs=-1, random_state=42)
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=-1, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
def plot_eval(pred, true):
    residuals = true - pred

    # Create a 2x3 grid of subplots
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))

    # Scatter plot of real vs. predicted values
    axes[0, 0].scatter(true, pred)
    axes[0, 0].set_xlabel('Real Values')
    axes[0, 0].set_ylabel('Predicted Values')
    axes[0, 0].set_title('Scatter Plot')

    # Residual plot
    axes[0, 1].scatter(pred, residuals)
    axes[0, 1].axhline(y=0, color='r', linestyle='--')
    axes[0, 1].set_xlabel('Predicted Values')
    axes[0, 1].set_ylabel('Residuals')
    axes[0, 1].set_title('Residual Plot')

    # Histogram of residuals
    axes[0, 2].hist(residuals, bins=20)
    axes[0, 2].set_xlabel('Residuals')
    axes[0, 2].set_ylabel('Frequency')
    axes[0, 2].set_title('Histogram of Residuals')

    # QQ plot
    stats.probplot(residuals.flatten(), plot=axes[1, 0])
    axes[1, 0].set_title('QQ Plot')

    # Regression line plot
    axes[1, 1].scatter(true, pred)
    axes[1, 1].plot(true, true, color='r', linestyle='--')
    axes[1, 1].set_xlabel('Real Values')
    axes[1, 1].set_ylabel('Predicted Values')
    axes[1, 1].set_title('Regression Line Plot')

    # R-squared and MSE values
    r2 = r2_score(true, pred)
    mse = mean_squared_error(true, pred)
    axes[1, 2].bar(['R-squared', 'MSE'], [r2, mse])
    axes[1, 2].set_title('R-squared and MSE')

    # Adjust layout and show plot
    plt.tight_layout()
    plt.show()

# %%
pred = model.predict(x_test)
print(f'test_data: {smape(y_test, pred)}')
plot_eval(pred*max_speed, y_test*max_speed)
# Out:
# test_data: 8.460633
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 pred = model.predict(x_test)
#       2 print(f'test_data: {smape(y_test, pred)}')
# ----> 3 plot_eval(pred*max_speed, y_test*max_speed)
#
# NameError: name 'max_speed' is not defined

# %%
pred = model.predict(x_train)
print(f'train_data: {smape(y_train, pred)}')
plot_eval(pred*max_speed, y_train*max_speed)
# Out:
# train_data: 8.303729

# %%
import optuna
from sklearn.model_selection import cross_val_score

def objective(trial):
    
    
    
    n_estimators = trial.suggest_int("n_estimators", 1000, 5000)
    max_depth = trial.suggest_int("max_depth", 1, 10)
    learning_rate = trial.suggest_float("learning_rate", 1e-6, 1e-1, log=True)
    gamma = trial.suggest_float("gamma", 0.1, 1.0, step=0.1)
    min_child_weight = trial.suggest_int("min_child_weight", 1, 7, step=2)
    subsample = trial.suggest_float("subsample", 0.5, 1.0, step=0.1)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1.0, step=0.1)
    reg_alpha = trial.suggest_float("reg_alpha", 0., 1.0, step=0.1)
    reg_lambda = trial.suggest_float("reg_lambda", 0., 1.0, step=0.1)
    seed = trial.suggest_int("random_state", 20, 50, step=2)
    
    
    model = xgboost.XGBRegressor(n_estimators=n_estimators,
                                max_depth=max_depth,
                                learning_rate=learning_rate,
                                gamma=gamma,
                                min_child_weight=min_child_weight,
                                colsample_bytree=colsample_bytree,
                                subsample=subsample,
                                reg_alpha=reg_alpha,
                                reg_lambda=reg_lambda,
                                n_jobs=-1, metric=mean_squared_error,
                                eval_metric=mean_squared_error,
                                random_state=seed
                                )
    
    model.fit(x_train, y_train)
    
    y_hat = model.predict(x_test)
    
    return mean_squared_error(y_test, y_hat, squared=True)

study = optuna.create_study()
study.optimize(objective, n_trials=20)
# Out:
# [I 2023-08-09 17:02:29,622] A new study created in memory with name: no-name-574b8b25-1e98-4aa3-a7c3-13777986582d
# [I 2023-08-09 17:05:04,526] Trial 0 finished with value: 34.3238397504761 and parameters: {'n_estimators': 1582, 'max_depth': 7, 'learning_rate': 0.0015717999989744102, 'gamma': 0.6, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.9, 'reg_alpha': 0.8, 'reg_lambda': 0.7000000000000001, 'random_state': 30}. Best is trial 0 with value: 34.3238397504761.
# [I 2023-08-09 17:11:34,552] Trial 1 finished with value: 90.31725635463336 and parameters: {'n_estimators': 3805, 'max_depth': 9, 'learning_rate': 0.0003912727767901208, 'gamma': 0.30000000000000004, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.4, 'reg_lambda': 0.30000000000000004, 'random_state': 44}. Best is trial 0 with value: 34.3238397504761.
# [I 2023-08-09 17:17:57,593] Trial 2 finished with value: 344.79465530262104 and parameters: {'n_estimators': 4066, 'max_depth': 7, 'learning_rate': 0.00017330322686865708, 'gamma': 0.7000000000000001, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.0, 'reg_lambda': 0.4, 'random_state': 36}. Best is trial 0 with value: 34.3238397504761.
# [I 2023-08-09 17:18:44,817] Trial 3 finished with value: 1265.959563356126 and parameters: {'n_estimators': 1093, 'max_depth': 3, 'learning_rate': 1.4401634675182872e-05, 'gamma': 1.0, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.6, 'reg_alpha': 0.9, 'reg_lambda': 0.6000000000000001, 'random_state': 30}. Best is trial 0 with value: 34.3238397504761.
# [I 2023-08-09 17:19:41,436] Trial 4 finished with value: 52.94898192273715 and parameters: {'n_estimators': 2725, 'max_depth': 1, 'learning_rate': 0.0010981296363332602, 'gamma': 0.1, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.1, 'random_state': 44}. Best is trial 0 with value: 34.3238397504761.
# [W 2023-08-09 17:27:31,216] Trial 5 failed with parameters: {'n_estimators': 4556, 'max_depth': 9, 'learning_rate': 0.0001621488250417651, 'gamma': 1.0, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.2, 'reg_lambda': 0.8, 'random_state': 44} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/mdaniyalk/miniforge3/lib/python3.10/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/vt/q06w72ls4kz7lg_wsqqw2f0h0000gp/T/ipykernel_44011/1798309048.py", line 34, in objective
#     model.fit(x_train, y_train)
#   File "/Users/mdaniyalk/miniforge3/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/Users/mdaniyalk/miniforge3/lib/python3.10/site-packages/xgboost/sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "/Users/mdaniyalk/miniforge3/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/Users/mdaniyalk/miniforge3/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/mdaniyalk/miniforge3/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
# KeyboardInterrupt
# [W 2023-08-09 17:27:31,222] Trial 5 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 41
#      38     return mean_squared_error(y_test, y_hat, squared=True)
#      40 study = optuna.create_study()
# ---> 41 study.optimize(objective, n_trials=20)
#
# File ~/miniforge3/lib/python3.10/site-packages/optuna/study/study.py:425, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     321 def optimize(
#     322     self,
#     323     func: ObjectiveFuncType,
#    (...)
#     330     show_progress_bar: bool = False,
#     331 ) -> None:
#     332     """Optimize an objective function.
#     333
#     334     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     422             If nested invocation of this method occurs.
#     423     """
# --> 425     _optimize(
#     426         study=self,
#     427         func=func,
#     428         n_trials=n_trials,
#     429         timeout=timeout,
#     430         n_jobs=n_jobs,
#     431         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     432         callbacks=callbacks,
#     433         gc_after_trial=gc_after_trial,
#     434         show_progress_bar=show_progress_bar,
#     435     )
#
# File ~/miniforge3/lib/python3.10/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/miniforge3/lib/python3.10/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/miniforge3/lib/python3.10/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/miniforge3/lib/python3.10/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[63], line 34, in objective(trial)
#      17 seed = trial.suggest_int("random_state", 20, 50, step=2)
#      20 model = xgboost.XGBRegressor(n_estimators=n_estimators,
#      21                             max_depth=max_depth,
#      22                             learning_rate=learning_rate,
#    (...)
#      31                             random_state=seed
#      32                             )
# ---> 34 model.fit(x_train, y_train)
#      36 y_hat = model.predict(x_test)
#      38 return mean_squared_error(y_test, y_hat, squared=True)
#
# File ~/miniforge3/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/xgboost/sklearn.py:1025, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1014     obj = None
#    1016 (
#    1017     model,
#    1018     metric,
#    (...)
#    1023     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1024 )
# -> 1025 self._Booster = train(
#    1026     params,
#    1027     train_dmatrix,
#    1028     self.get_num_boosting_rounds(),
#    1029     evals=evals,
#    1030     early_stopping_rounds=early_stopping_rounds,
#    1031     evals_result=evals_result,
#    1032     obj=obj,
#    1033     custom_metric=metric,
#    1034     verbose_eval=verbose,
#    1035     xgb_model=model,
#    1036     callbacks=callbacks,
#    1037 )
#    1039 self._set_evaluation_result(evals_result)
#    1040 return self
#
# File ~/miniforge3/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/miniforge3/lib/python3.10/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# [I 2023-08-09 15:01:50,824] Trial 13 finished with value: 3.5698679194559 and parameters: {'n_estimators': 2590, 'max_depth': 8, 'learning_rate': 0.010898852917742244, 'gamma': 0.30000000000000004, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.30000000000000004, 'reg_lambda': 0.5, 'random_state': 26}. Best is trial 12 with value: 3.5533699042727336.
# [I 2023-08-09 15:17:28,806] Trial 15 finished with value: 3.5449906803696667 and parameters: {'n_estimators': 2552, 'max_depth': 9, 'learning_rate': 0.010419707354527082, 'gamma': 0.30000000000000004, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.30000000000000004, 'reg_lambda': 0.5, 'random_state': 28}. Best is trial 15 with value: 3.5449906803696667.
# [I 2023-08-09 14:56:21,431] Trial 12 finished with value: 3.5533699042727336 and parameters: {'n_estimators': 4255, 'max_depth': 7, 'learning_rate': 0.011679890124365775, 'gamma': 0.1, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.5, 'reg_lambda': 0.2, 'random_state': 26}. Best is trial 12 with value: 3.5533699042727336.

# %%
import optuna
from sklearn.model_selection import cross_val_score

def objective(trial):
    
    
    subsample_for_bin = trial.suggest_int("subsample_for_bin", 100000, 300000)
    n_estimators = trial.suggest_int("n_estimators", 1000, 5000)
    max_depth = trial.suggest_int("max_depth", 1, 10)
    learning_rate = trial.suggest_float("learning_rate", 1e-6, 1e-1, log=True)
    num_leaves = trial.suggest_int("num_leaves", 10, 50)
    min_child_weight = trial.suggest_int("min_child_weight", 1, 7, step=2)
    subsample = trial.suggest_float("subsample", 0.5, 1.0, step=0.1)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1.0, step=0.1)
    reg_alpha = trial.suggest_float("reg_alpha", 0., 1.0, step=0.1)
    reg_lambda = trial.suggest_float("reg_lambda", 0., 1.0, step=0.1)
    seed = trial.suggest_int("random_state", 20, 50, step=2)
    min_child_samples = trial.suggest_int("min_child_samples", 10, 50)
    
    model = lgb.LGBMRegressor(num_leaves=num_leaves, max_depth=max_depth, learning_rate=learning_rate, 
                              n_estimators=n_estimators, subsample_for_bin=subsample_for_bin, 
                              min_child_weight=min_child_weight, min_child_samples=min_child_samples, subsample=subsample, 
                              colsample_bytree=colsample_bytree, reg_alpha=reg_alpha, 
                              reg_lambda=reg_lambda, random_state=seed, n_jobs=-1,)
    
    model.fit(x_train, y_train)
    
    y_hat = model.predict(x_test)
    
    return mean_squared_error(y_test, y_hat, squared=True)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-08-09 16:13:35,417] A new study created in memory with name: no-name-4ab2c4d9-73a4-4812-8989-ec16abbf0e8b
# [I 2023-08-09 16:13:43,370] Trial 0 finished with value: 51.59595973389644 and parameters: {'subsample_for_bin': 294457, 'n_estimators': 4319, 'max_depth': 1, 'learning_rate': 0.0004933991512255601, 'num_leaves': 21, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1, 'reg_lambda': 0.30000000000000004, 'random_state': 48, 'min_child_samples': 26}. Best is trial 0 with value: 51.59595973389644.
# [I 2023-08-09 16:14:16,876] Trial 1 finished with value: 63.698866506844546 and parameters: {'subsample_for_bin': 179193, 'n_estimators': 2598, 'max_depth': 9, 'learning_rate': 1.8855435527620165e-05, 'num_leaves': 45, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 0.30000000000000004, 'random_state': 28, 'min_child_samples': 49}. Best is trial 0 with value: 51.59595973389644.
# [I 2023-08-09 16:14:52,816] Trial 2 finished with value: 29.323666201114136 and parameters: {'subsample_for_bin': 104393, 'n_estimators': 4931, 'max_depth': 5, 'learning_rate': 0.0008816931217800893, 'num_leaves': 14, 'min_child_weight': 3, 'subsample': 0.5, 'colsample_bytree': 0.6, 'reg_alpha': 0.8, 'reg_lambda': 0.0, 'random_state': 30, 'min_child_samples': 19}. Best is trial 2 with value: 29.323666201114136.
# [I 2023-08-09 16:15:39,800] Trial 3 finished with value: 17.725981250067427 and parameters: {'subsample_for_bin': 254011, 'n_estimators': 4834, 'max_depth': 8, 'learning_rate': 0.003985358186063978, 'num_leaves': 21, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.5, 'reg_alpha': 0.5, 'reg_lambda': 1.0, 'random_state': 32, 'min_child_samples': 12}. Best is trial 3 with value: 17.725981250067427.
# [I 2023-08-09 16:16:04,529] Trial 4 finished with value: 21.689670581062018 and parameters: {'subsample_for_bin': 249232, 'n_estimators': 2288, 'max_depth': 6, 'learning_rate': 0.0027557155275881287, 'num_leaves': 49, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.9, 'reg_alpha': 0.30000000000000004, 'reg_lambda': 0.4, 'random_state': 30, 'min_child_samples': 13}. Best is trial 3 with value: 17.725981250067427.
# [I 2023-08-09 16:16:49,886] Trial 5 finished with value: 47.019248847141746 and parameters: {'subsample_for_bin': 254385, 'n_estimators': 4059, 'max_depth': 6, 'learning_rate': 0.00015966972687994144, 'num_leaves': 42, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 1.0, 'random_state': 42, 'min_child_samples': 43}. Best is trial 3 with value: 17.725981250067427.
# [I 2023-08-09 16:17:18,970] Trial 6 finished with value: 61.06539025505221 and parameters: {'subsample_for_bin': 213818, 'n_estimators': 3373, 'max_depth': 7, 'learning_rate': 3.4559466598213035e-05, 'num_leaves': 24, 'min_child_weight': 7, 'subsample': 0.5, 'colsample_bytree': 0.8, 'reg_alpha': 0.4, 'reg_lambda': 0.8, 'random_state': 30, 'min_child_samples': 33}. Best is trial 3 with value: 17.725981250067427.
# [I 2023-08-09 16:17:30,117] Trial 7 finished with value: 33.43911456444462 and parameters: {'subsample_for_bin': 128611, 'n_estimators': 1511, 'max_depth': 6, 'learning_rate': 0.0013536933013995117, 'num_leaves': 22, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.6, 'reg_alpha': 0.1, 'reg_lambda': 0.5, 'random_state': 38, 'min_child_samples': 40}. Best is trial 3 with value: 17.725981250067427.
# [I 2023-08-09 16:17:43,674] Trial 8 finished with value: 63.378793055621635 and parameters: {'subsample_for_bin': 199846, 'n_estimators': 2127, 'max_depth': 5, 'learning_rate': 3.7740160036823835e-05, 'num_leaves': 20, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.5, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.9, 'random_state': 40, 'min_child_samples': 42}. Best is trial 3 with value: 17.725981250067427.
# [I 2023-08-09 16:17:53,867] Trial 9 finished with value: 42.411975229927215 and parameters: {'subsample_for_bin': 284450, 'n_estimators': 1297, 'max_depth': 7, 'learning_rate': 0.0006711734907685014, 'num_leaves': 26, 'min_child_weight': 7, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.0, 'reg_lambda': 0.30000000000000004, 'random_state': 22, 'min_child_samples': 34}. Best is trial 3 with value: 17.725981250067427.
# [I 2023-08-09 16:18:20,383] Trial 10 finished with value: 12.944289145464419 and parameters: {'subsample_for_bin': 157283, 'n_estimators': 3402, 'max_depth': 10, 'learning_rate': 0.03998828364407165, 'num_leaves': 36, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 22, 'min_child_samples': 11}. Best is trial 10 with value: 12.944289145464419.
# [I 2023-08-09 16:18:46,122] Trial 11 finished with value: 12.898013441276426 and parameters: {'subsample_for_bin': 154860, 'n_estimators': 3417, 'max_depth': 10, 'learning_rate': 0.04030421942798578, 'num_leaves': 35, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 20, 'min_child_samples': 10}. Best is trial 11 with value: 12.898013441276426.
# [I 2023-08-09 16:19:16,552] Trial 12 finished with value: 12.784408965378056 and parameters: {'subsample_for_bin': 151893, 'n_estimators': 3339, 'max_depth': 10, 'learning_rate': 0.062052822438907904, 'num_leaves': 36, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 20, 'min_child_samples': 20}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:19:40,932] Trial 13 finished with value: 12.805674737671618 and parameters: {'subsample_for_bin': 151503, 'n_estimators': 3152, 'max_depth': 10, 'learning_rate': 0.089046901559066, 'num_leaves': 34, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 20, 'min_child_samples': 21}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:19:49,624] Trial 14 finished with value: 20.26231153338619 and parameters: {'subsample_for_bin': 140548, 'n_estimators': 2824, 'max_depth': 2, 'learning_rate': 0.0578520608140813, 'num_leaves': 33, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.8, 'reg_lambda': 0.6000000000000001, 'random_state': 24, 'min_child_samples': 24}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:20:39,694] Trial 15 finished with value: 65.95299786368948 and parameters: {'subsample_for_bin': 111254, 'n_estimators': 3897, 'max_depth': 9, 'learning_rate': 1.3578735907119776e-06, 'num_leaves': 39, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.8, 'reg_lambda': 0.8, 'random_state': 26, 'min_child_samples': 19}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:20:51,445] Trial 16 finished with value: 21.197088140499027 and parameters: {'subsample_for_bin': 184657, 'n_estimators': 3079, 'max_depth': 3, 'learning_rate': 0.011049851852021403, 'num_leaves': 29, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.6000000000000001, 'random_state': 20, 'min_child_samples': 19}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:21:18,653] Trial 17 finished with value: 12.803192403215784 and parameters: {'subsample_for_bin': 171907, 'n_estimators': 3848, 'max_depth': 9, 'learning_rate': 0.07535337002451474, 'num_leaves': 30, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.1, 'random_state': 36, 'min_child_samples': 26}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:21:35,325] Trial 18 finished with value: 16.641228176667088 and parameters: {'subsample_for_bin': 222593, 'n_estimators': 3746, 'max_depth': 8, 'learning_rate': 0.013568442960761422, 'num_leaves': 11, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.1, 'random_state': 36, 'min_child_samples': 29}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:21:44,167] Trial 19 finished with value: 18.325385597527703 and parameters: {'subsample_for_bin': 187092, 'n_estimators': 1990, 'max_depth': 4, 'learning_rate': 0.01570528224249938, 'num_leaves': 29, 'min_child_weight': 7, 'subsample': 1.0, 'colsample_bytree': 0.8, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.1, 'random_state': 46, 'min_child_samples': 31}. Best is trial 12 with value: 12.784408965378056.
# [I 2023-08-09 16:22:20,427] Trial 20 finished with value: 12.632046239464408 and parameters: {'subsample_for_bin': 123830, 'n_estimators': 4556, 'max_depth': 9, 'learning_rate': 0.07980677879578675, 'num_leaves': 40, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.9, 'reg_lambda': 0.2, 'random_state': 34, 'min_child_samples': 16}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:22:56,290] Trial 21 finished with value: 12.827773073727645 and parameters: {'subsample_for_bin': 128584, 'n_estimators': 4383, 'max_depth': 9, 'learning_rate': 0.07913223726038005, 'num_leaves': 39, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.9, 'reg_lambda': 0.1, 'random_state': 34, 'min_child_samples': 16}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:23:39,944] Trial 22 finished with value: 12.865190580227326 and parameters: {'subsample_for_bin': 163955, 'n_estimators': 4466, 'max_depth': 8, 'learning_rate': 0.025012645127326018, 'num_leaves': 43, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.2, 'random_state': 44, 'min_child_samples': 24}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:24:17,025] Trial 23 finished with value: 13.03081119605048 and parameters: {'subsample_for_bin': 125141, 'n_estimators': 3653, 'max_depth': 9, 'learning_rate': 0.0956255348398092, 'num_leaves': 48, 'min_child_weight': 5, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.0, 'random_state': 50, 'min_child_samples': 16}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:25:05,045] Trial 24 finished with value: 14.391279496248192 and parameters: {'subsample_for_bin': 174854, 'n_estimators': 4636, 'max_depth': 10, 'learning_rate': 0.006753462261526557, 'num_leaves': 39, 'min_child_weight': 7, 'subsample': 1.0, 'colsample_bytree': 0.8, 'reg_alpha': 0.9, 'reg_lambda': 0.4, 'random_state': 36, 'min_child_samples': 27}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:25:33,196] Trial 25 finished with value: 13.233762117419904 and parameters: {'subsample_for_bin': 139891, 'n_estimators': 4062, 'max_depth': 7, 'learning_rate': 0.026786247953823856, 'num_leaves': 30, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.8, 'reg_lambda': 0.2, 'random_state': 40, 'min_child_samples': 15}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:26:07,099] Trial 26 finished with value: 14.70673142801877 and parameters: {'subsample_for_bin': 114049, 'n_estimators': 4099, 'max_depth': 8, 'learning_rate': 0.0072023284945756825, 'num_leaves': 32, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 1.0, 'reg_lambda': 0.5, 'random_state': 34, 'min_child_samples': 22}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:26:36,234] Trial 27 finished with value: 13.200551258562744 and parameters: {'subsample_for_bin': 169955, 'n_estimators': 3623, 'max_depth': 9, 'learning_rate': 0.02431906154042803, 'num_leaves': 37, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.2, 'random_state': 26, 'min_child_samples': 37}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:26:53,789] Trial 28 finished with value: 13.498860122633163 and parameters: {'subsample_for_bin': 140416, 'n_estimators': 2707, 'max_depth': 10, 'learning_rate': 0.03900141906291841, 'num_leaves': 26, 'min_child_weight': 7, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.0, 'random_state': 38, 'min_child_samples': 27}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:27:02,044] Trial 29 finished with value: 42.789012427831516 and parameters: {'subsample_for_bin': 203229, 'n_estimators': 4613, 'max_depth': 1, 'learning_rate': 0.0028442892419202736, 'num_leaves': 46, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.4, 'random_state': 44, 'min_child_samples': 24}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:27:40,654] Trial 30 finished with value: 13.565645100503097 and parameters: {'subsample_for_bin': 100232, 'n_estimators': 4212, 'max_depth': 8, 'learning_rate': 0.012094379622414707, 'num_leaves': 42, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.8, 'reg_lambda': 0.5, 'random_state': 48, 'min_child_samples': 21}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:28:02,081] Trial 31 finished with value: 12.86705316760753 and parameters: {'subsample_for_bin': 153458, 'n_estimators': 3104, 'max_depth': 10, 'learning_rate': 0.09229516215131037, 'num_leaves': 33, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 24, 'min_child_samples': 17}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:28:25,930] Trial 32 finished with value: 12.904736823038478 and parameters: {'subsample_for_bin': 146424, 'n_estimators': 3256, 'max_depth': 9, 'learning_rate': 0.04566005484290537, 'num_leaves': 37, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.8, 'random_state': 26, 'min_child_samples': 21}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:28:42,625] Trial 33 finished with value: 12.7860067916698 and parameters: {'subsample_for_bin': 120820, 'n_estimators': 2484, 'max_depth': 10, 'learning_rate': 0.09417283416250327, 'num_leaves': 34, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.9, 'reg_lambda': 0.6000000000000001, 'random_state': 20, 'min_child_samples': 26}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:28:59,206] Trial 34 finished with value: 13.729179735808152 and parameters: {'subsample_for_bin': 117585, 'n_estimators': 2266, 'max_depth': 9, 'learning_rate': 0.026260880349328906, 'num_leaves': 31, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.9, 'reg_lambda': 0.6000000000000001, 'random_state': 32, 'min_child_samples': 30}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:29:13,872] Trial 35 finished with value: 13.04695591239653 and parameters: {'subsample_for_bin': 128131, 'n_estimators': 1758, 'max_depth': 10, 'learning_rate': 0.04675292902553558, 'num_leaves': 40, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.4, 'reg_lambda': 0.30000000000000004, 'random_state': 28, 'min_child_samples': 14}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:29:27,201] Trial 36 finished with value: 13.007035739991935 and parameters: {'subsample_for_bin': 166188, 'n_estimators': 2497, 'max_depth': 9, 'learning_rate': 0.09716819343015357, 'num_leaves': 18, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'reg_alpha': 0.8, 'reg_lambda': 0.30000000000000004, 'random_state': 22, 'min_child_samples': 26}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:29:49,949] Trial 37 finished with value: 17.666767669571342 and parameters: {'subsample_for_bin': 191974, 'n_estimators': 2915, 'max_depth': 7, 'learning_rate': 0.004856299462401904, 'num_leaves': 27, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.9, 'random_state': 32, 'min_child_samples': 49}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:30:35,372] Trial 38 finished with value: 13.101387038699404 and parameters: {'subsample_for_bin': 119444, 'n_estimators': 4942, 'max_depth': 8, 'learning_rate': 0.019181618527619446, 'num_leaves': 44, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.5, 'reg_lambda': 0.6000000000000001, 'random_state': 28, 'min_child_samples': 18}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:31:04,702] Trial 39 finished with value: 15.482556772110481 and parameters: {'subsample_for_bin': 106825, 'n_estimators': 2563, 'max_depth': 10, 'learning_rate': 0.006338421224730631, 'num_leaves': 47, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0.2, 'reg_lambda': 0.1, 'random_state': 30, 'min_child_samples': 33}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:31:53,772] Trial 40 finished with value: 17.085295685945514 and parameters: {'subsample_for_bin': 138169, 'n_estimators': 3917, 'max_depth': 9, 'learning_rate': 0.0024549529154178386, 'num_leaves': 50, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 0.9, 'random_state': 24, 'min_child_samples': 13}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:32:18,740] Trial 41 finished with value: 12.788105455439403 and parameters: {'subsample_for_bin': 147848, 'n_estimators': 3198, 'max_depth': 10, 'learning_rate': 0.061250167641757954, 'num_leaves': 34, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 20, 'min_child_samples': 22}. Best is trial 20 with value: 12.632046239464408.
# [I 2023-08-09 16:32:43,187] Trial 42 finished with value: 12.544927061084758 and parameters: {'subsample_for_bin': 177013, 'n_estimators': 3509, 'max_depth': 10, 'learning_rate': 0.055754214181656374, 'num_leaves': 35, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.8, 'random_state': 22, 'min_child_samples': 23}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:33:09,119] Trial 43 finished with value: 12.856066817496101 and parameters: {'subsample_for_bin': 160463, 'n_estimators': 3458, 'max_depth': 10, 'learning_rate': 0.05134188956884886, 'num_leaves': 41, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.8, 'random_state': 22, 'min_child_samples': 23}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:33:27,444] Trial 44 finished with value: 13.041627277437353 and parameters: {'subsample_for_bin': 133617, 'n_estimators': 2422, 'max_depth': 10, 'learning_rate': 0.03561144187070769, 'num_leaves': 37, 'min_child_weight': 3, 'subsample': 0.7, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 20, 'min_child_samples': 19}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:33:50,601] Trial 45 finished with value: 14.872236503165047 and parameters: {'subsample_for_bin': 222544, 'n_estimators': 2725, 'max_depth': 10, 'learning_rate': 0.00993116623184779, 'num_leaves': 34, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 1.0, 'random_state': 22, 'min_child_samples': 28}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:34:17,776] Trial 46 finished with value: 13.566202138174782 and parameters: {'subsample_for_bin': 147587, 'n_estimators': 2948, 'max_depth': 10, 'learning_rate': 0.01788607978302774, 'num_leaves': 35, 'min_child_weight': 3, 'subsample': 0.7, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.9, 'random_state': 20, 'min_child_samples': 25}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:34:40,725] Trial 47 finished with value: 12.782269896391169 and parameters: {'subsample_for_bin': 180052, 'n_estimators': 3320, 'max_depth': 9, 'learning_rate': 0.05631739469021249, 'num_leaves': 36, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.6000000000000001, 'random_state': 24, 'min_child_samples': 46}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:34:57,988] Trial 48 finished with value: 13.844517665708304 and parameters: {'subsample_for_bin': 199626, 'n_estimators': 1962, 'max_depth': 7, 'learning_rate': 0.03195360094615711, 'num_leaves': 37, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.5, 'reg_alpha': 0.8, 'reg_lambda': 0.6000000000000001, 'random_state': 24, 'min_child_samples': 42}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:35:33,960] Trial 49 finished with value: 12.775868961359675 and parameters: {'subsample_for_bin': 179691, 'n_estimators': 3525, 'max_depth': 6, 'learning_rate': 0.05811241342006619, 'num_leaves': 45, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.5, 'random_state': 28, 'min_child_samples': 36}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:36:08,592] Trial 50 finished with value: 13.452322456350323 and parameters: {'subsample_for_bin': 180759, 'n_estimators': 3523, 'max_depth': 6, 'learning_rate': 0.01768640727654272, 'num_leaves': 44, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.8, 'random_state': 28, 'min_child_samples': 50}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:36:32,185] Trial 51 finished with value: 12.925059934476241 and parameters: {'subsample_for_bin': 178784, 'n_estimators': 3279, 'max_depth': 5, 'learning_rate': 0.06233413820800207, 'num_leaves': 41, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.5, 'random_state': 22, 'min_child_samples': 48}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:36:35,676] Trial 52 finished with value: 18.500380994288008 and parameters: {'subsample_for_bin': 209664, 'n_estimators': 1070, 'max_depth': 3, 'learning_rate': 0.059035789874389726, 'num_leaves': 38, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 1.0, 'reg_alpha': 0.8, 'reg_lambda': 0.6000000000000001, 'random_state': 26, 'min_child_samples': 44}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:37:05,209] Trial 53 finished with value: 12.93761655070489 and parameters: {'subsample_for_bin': 192536, 'n_estimators': 3810, 'max_depth': 8, 'learning_rate': 0.03938206834260603, 'num_leaves': 35, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.9, 'reg_lambda': 0.7000000000000001, 'random_state': 24, 'min_child_samples': 35}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:37:24,597] Trial 54 finished with value: 13.758233941267465 and parameters: {'subsample_for_bin': 160341, 'n_estimators': 3545, 'max_depth': 4, 'learning_rate': 0.060341407216914916, 'num_leaves': 45, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 1.0, 'reg_lambda': 0.4, 'random_state': 22, 'min_child_samples': 38}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:37:51,855] Trial 55 finished with value: 13.366164531536734 and parameters: {'subsample_for_bin': 246512, 'n_estimators': 3333, 'max_depth': 9, 'learning_rate': 0.02788690964647813, 'num_leaves': 32, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.9, 'reg_lambda': 0.5, 'random_state': 24, 'min_child_samples': 32}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:38:18,776] Trial 56 finished with value: 14.41704253636642 and parameters: {'subsample_for_bin': 187466, 'n_estimators': 2798, 'max_depth': 9, 'learning_rate': 0.010090248098801477, 'num_leaves': 41, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.9, 'reg_lambda': 0.8, 'random_state': 20, 'min_child_samples': 46}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:38:39,127] Trial 57 finished with value: 12.947137699169701 and parameters: {'subsample_for_bin': 299123, 'n_estimators': 3010, 'max_depth': 8, 'learning_rate': 0.09433213359217935, 'num_leaves': 39, 'min_child_weight': 3, 'subsample': 0.7, 'colsample_bytree': 1.0, 'reg_alpha': 1.0, 'reg_lambda': 0.7000000000000001, 'random_state': 30, 'min_child_samples': 39}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:38:55,885] Trial 58 finished with value: 16.071220561446303 and parameters: {'subsample_for_bin': 176458, 'n_estimators': 3694, 'max_depth': 4, 'learning_rate': 0.0156563285130182, 'num_leaves': 28, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.8, 'reg_lambda': 0.6000000000000001, 'random_state': 26, 'min_child_samples': 36}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:39:11,614] Trial 59 finished with value: 12.671825296096822 and parameters: {'subsample_for_bin': 168756, 'n_estimators': 2311, 'max_depth': 6, 'learning_rate': 0.0688008635760832, 'num_leaves': 36, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.8, 'reg_lambda': 0.6000000000000001, 'random_state': 30, 'min_child_samples': 20}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:39:42,345] Trial 60 finished with value: 12.737754287332589 and parameters: {'subsample_for_bin': 165813, 'n_estimators': 3993, 'max_depth': 7, 'learning_rate': 0.033592791883699576, 'num_leaves': 43, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.5, 'random_state': 32, 'min_child_samples': 11}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:40:16,086] Trial 61 finished with value: 12.751820398887912 and parameters: {'subsample_for_bin': 166713, 'n_estimators': 4234, 'max_depth': 6, 'learning_rate': 0.03638730010203074, 'num_leaves': 43, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.5, 'random_state': 32, 'min_child_samples': 12}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:40:53,447] Trial 62 finished with value: 12.840157442627705 and parameters: {'subsample_for_bin': 165803, 'n_estimators': 4700, 'max_depth': 6, 'learning_rate': 0.03463042762044364, 'num_leaves': 43, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.5, 'random_state': 34, 'min_child_samples': 10}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:41:21,590] Trial 63 finished with value: 13.389236801554807 and parameters: {'subsample_for_bin': 170351, 'n_estimators': 4226, 'max_depth': 5, 'learning_rate': 0.022226848267817637, 'num_leaves': 48, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.4, 'reg_lambda': 0.4, 'random_state': 30, 'min_child_samples': 12}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:41:54,816] Trial 64 finished with value: 12.684368570077428 and parameters: {'subsample_for_bin': 194239, 'n_estimators': 3965, 'max_depth': 6, 'learning_rate': 0.0471337116717514, 'num_leaves': 46, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.5, 'random_state': 32, 'min_child_samples': 12}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:42:32,976] Trial 65 finished with value: 12.710622458123293 and parameters: {'subsample_for_bin': 216884, 'n_estimators': 4492, 'max_depth': 6, 'learning_rate': 0.03709788981988562, 'num_leaves': 45, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.4, 'random_state': 32, 'min_child_samples': 11}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:43:12,296] Trial 66 finished with value: 12.890221259642102 and parameters: {'subsample_for_bin': 236188, 'n_estimators': 4440, 'max_depth': 6, 'learning_rate': 0.032588540147918725, 'num_leaves': 47, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 32, 'min_child_samples': 12}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:43:54,940] Trial 67 finished with value: 13.264815847736283 and parameters: {'subsample_for_bin': 220835, 'n_estimators': 4801, 'max_depth': 7, 'learning_rate': 0.013317828287661003, 'num_leaves': 43, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.4, 'random_state': 34, 'min_child_samples': 14}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:44:21,410] Trial 68 finished with value: 13.601343739929826 and parameters: {'subsample_for_bin': 203910, 'n_estimators': 3981, 'max_depth': 5, 'learning_rate': 0.021247986664759265, 'num_leaves': 49, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.4, 'random_state': 32, 'min_child_samples': 11}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:44:58,146] Trial 69 finished with value: 12.947802644697662 and parameters: {'subsample_for_bin': 214484, 'n_estimators': 4278, 'max_depth': 6, 'learning_rate': 0.04343770939689261, 'num_leaves': 46, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.5, 'random_state': 36, 'min_child_samples': 15}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:45:28,732] Trial 70 finished with value: 12.984463644221998 and parameters: {'subsample_for_bin': 231962, 'n_estimators': 4460, 'max_depth': 5, 'learning_rate': 0.0698083710695798, 'num_leaves': 42, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.2, 'random_state': 38, 'min_child_samples': 17}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:46:01,385] Trial 71 finished with value: 12.870769444266092 and parameters: {'subsample_for_bin': 193230, 'n_estimators': 4118, 'max_depth': 7, 'learning_rate': 0.04700557113697748, 'num_leaves': 44, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.4, 'reg_lambda': 0.5, 'random_state': 30, 'min_child_samples': 10}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:46:35,885] Trial 72 finished with value: 13.038867100280342 and parameters: {'subsample_for_bin': 285781, 'n_estimators': 4376, 'max_depth': 6, 'learning_rate': 0.07068722175168451, 'num_leaves': 40, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.5, 'random_state': 34, 'min_child_samples': 13}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:47:16,046] Trial 73 finished with value: 12.860584637197846 and parameters: {'subsample_for_bin': 186616, 'n_estimators': 4577, 'max_depth': 6, 'learning_rate': 0.024674899357959645, 'num_leaves': 45, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.4, 'random_state': 32, 'min_child_samples': 15}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:47:52,314] Trial 74 finished with value: 12.863380635618359 and parameters: {'subsample_for_bin': 199501, 'n_estimators': 4171, 'max_depth': 7, 'learning_rate': 0.03297939887459067, 'num_leaves': 47, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.5, 'random_state': 28, 'min_child_samples': 11}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:48:25,711] Trial 75 finished with value: 12.605559430554653 and parameters: {'subsample_for_bin': 175338, 'n_estimators': 4007, 'max_depth': 6, 'learning_rate': 0.07286433620378673, 'num_leaves': 45, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 32, 'min_child_samples': 17}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:48:53,619] Trial 76 finished with value: 12.850388053344211 and parameters: {'subsample_for_bin': 172249, 'n_estimators': 3994, 'max_depth': 5, 'learning_rate': 0.09889154448249302, 'num_leaves': 42, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.2, 'random_state': 30, 'min_child_samples': 17}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:49:30,882] Trial 77 finished with value: 12.860260955653661 and parameters: {'subsample_for_bin': 210043, 'n_estimators': 4780, 'max_depth': 6, 'learning_rate': 0.07594914538896831, 'num_leaves': 40, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 32, 'min_child_samples': 14}. Best is trial 42 with value: 12.544927061084758.
# [I 2023-08-09 16:50:04,570] Trial 78 finished with value: 12.534454690626298 and parameters: {'subsample_for_bin': 155546, 'n_estimators': 3768, 'max_depth': 7, 'learning_rate': 0.04067420520019853, 'num_leaves': 50, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 16}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:50:40,129] Trial 79 finished with value: 13.19168692053072 and parameters: {'subsample_for_bin': 156548, 'n_estimators': 3770, 'max_depth': 7, 'learning_rate': 0.019764565731441624, 'num_leaves': 50, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.5, 'reg_lambda': 0.30000000000000004, 'random_state': 36, 'min_child_samples': 20}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:51:16,722] Trial 80 finished with value: 13.542890711874882 and parameters: {'subsample_for_bin': 262466, 'n_estimators': 3867, 'max_depth': 7, 'learning_rate': 0.011832334453479957, 'num_leaves': 49, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'reg_alpha': 0.30000000000000004, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 18}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:51:53,816] Trial 81 finished with value: 12.793799752542391 and parameters: {'subsample_for_bin': 164766, 'n_estimators': 4302, 'max_depth': 6, 'learning_rate': 0.04318866006491628, 'num_leaves': 46, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.2, 'random_state': 34, 'min_child_samples': 12}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:52:24,985] Trial 82 finished with value: 13.272885173196116 and parameters: {'subsample_for_bin': 158877, 'n_estimators': 4563, 'max_depth': 5, 'learning_rate': 0.030676225396485228, 'num_leaves': 44, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.4, 'random_state': 32, 'min_child_samples': 13}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:52:58,566] Trial 83 finished with value: 12.82592132187475 and parameters: {'subsample_for_bin': 168267, 'n_estimators': 4018, 'max_depth': 7, 'learning_rate': 0.04506047107586065, 'num_leaves': 48, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.4, 'reg_lambda': 0.30000000000000004, 'random_state': 36, 'min_child_samples': 15}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:53:31,646] Trial 84 finished with value: 12.853226500287873 and parameters: {'subsample_for_bin': 151367, 'n_estimators': 4130, 'max_depth': 6, 'learning_rate': 0.0730563031185076, 'num_leaves': 43, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.4, 'random_state': 32, 'min_child_samples': 16}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:53:58,865] Trial 85 finished with value: 13.253891964372315 and parameters: {'subsample_for_bin': 172759, 'n_estimators': 3619, 'max_depth': 7, 'learning_rate': 0.02580126487444692, 'num_leaves': 38, 'min_child_weight': 7, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.2, 'random_state': 40, 'min_child_samples': 18}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:54:28,615] Trial 86 finished with value: 12.936644891948257 and parameters: {'subsample_for_bin': 194801, 'n_estimators': 4371, 'max_depth': 5, 'learning_rate': 0.07571960786470913, 'num_leaves': 46, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.4, 'random_state': 30, 'min_child_samples': 11}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:55:03,137] Trial 87 finished with value: 13.209489988653454 and parameters: {'subsample_for_bin': 143780, 'n_estimators': 3901, 'max_depth': 6, 'learning_rate': 0.050726458528264906, 'num_leaves': 50, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 38, 'min_child_samples': 14}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:55:43,755] Trial 88 finished with value: 12.584975242666031 and parameters: {'subsample_for_bin': 153175, 'n_estimators': 4889, 'max_depth': 6, 'learning_rate': 0.0365093504186475, 'num_leaves': 42, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.4, 'random_state': 34, 'min_child_samples': 20}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:56:24,305] Trial 89 finished with value: 13.2682599436511 and parameters: {'subsample_for_bin': 183763, 'n_estimators': 4941, 'max_depth': 7, 'learning_rate': 0.014521580796899218, 'num_leaves': 38, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.4, 'random_state': 34, 'min_child_samples': 20}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:56:35,810] Trial 90 finished with value: 12.77248999351819 and parameters: {'subsample_for_bin': 137783, 'n_estimators': 1632, 'max_depth': 8, 'learning_rate': 0.09920295068618916, 'num_leaves': 41, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.8, 'reg_lambda': 0.2, 'random_state': 36, 'min_child_samples': 22}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:57:16,986] Trial 91 finished with value: 12.742715587797724 and parameters: {'subsample_for_bin': 152956, 'n_estimators': 4861, 'max_depth': 6, 'learning_rate': 0.03353549891844952, 'num_leaves': 43, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.6000000000000001, 'reg_lambda': 0.5, 'random_state': 32, 'min_child_samples': 19}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:57:56,921] Trial 92 finished with value: 12.60551060432992 and parameters: {'subsample_for_bin': 133452, 'n_estimators': 4882, 'max_depth': 6, 'learning_rate': 0.05165682611816454, 'num_leaves': 42, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 19}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:58:36,247] Trial 93 finished with value: 12.533047460664628 and parameters: {'subsample_for_bin': 131673, 'n_estimators': 4510, 'max_depth': 6, 'learning_rate': 0.054834260577325884, 'num_leaves': 47, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 16}. Best is trial 93 with value: 12.533047460664628.
# [I 2023-08-09 16:59:18,331] Trial 94 finished with value: 12.537393523821807 and parameters: {'subsample_for_bin': 122882, 'n_estimators': 4687, 'max_depth': 6, 'learning_rate': 0.05337881441549043, 'num_leaves': 48, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 17}. Best is trial 93 with value: 12.533047460664628.
# [I 2023-08-09 16:59:54,940] Trial 95 finished with value: 12.699034798127302 and parameters: {'subsample_for_bin': 133049, 'n_estimators': 4999, 'max_depth': 5, 'learning_rate': 0.061143541068345394, 'num_leaves': 48, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.8, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 17}. Best is trial 93 with value: 12.533047460664628.
# [I 2023-08-09 17:00:39,925] Trial 96 finished with value: 12.562349871059475 and parameters: {'subsample_for_bin': 123769, 'n_estimators': 4675, 'max_depth': 6, 'learning_rate': 0.051579509900114236, 'num_leaves': 47, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 21}. Best is trial 93 with value: 12.533047460664628.
# [I 2023-08-09 17:01:27,298] Trial 97 finished with value: 12.915690528076643 and parameters: {'subsample_for_bin': 125070, 'n_estimators': 4687, 'max_depth': 6, 'learning_rate': 0.06870414846218574, 'num_leaves': 49, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 36, 'min_child_samples': 20}. Best is trial 93 with value: 12.533047460664628.
# [I 2023-08-09 17:02:00,301] Trial 98 finished with value: 12.713922534370116 and parameters: {'subsample_for_bin': 108639, 'n_estimators': 4710, 'max_depth': 5, 'learning_rate': 0.07885743302142599, 'num_leaves': 48, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.5, 'reg_alpha': 0.8, 'reg_lambda': 0.2, 'random_state': 38, 'min_child_samples': 21}. Best is trial 93 with value: 12.533047460664628.
# [I 2023-08-09 17:02:22,609] Trial 99 finished with value: 14.12959962936557 and parameters: {'subsample_for_bin': 132751, 'n_estimators': 4853, 'max_depth': 4, 'learning_rate': 0.025867522717989578, 'num_leaves': 47, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.8, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 23}. Best is trial 93 with value: 12.533047460664628.

# %% [markdown]
# [I 2023-08-09 16:50:04,570] Trial 78 finished with value: 12.534454690626298 and parameters: {'subsample_for_bin': 155546, 'n_estimators': 3768, 'max_depth': 7, 'learning_rate': 0.04067420520019853, 'num_leaves': 50, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 16}. Best is trial 78 with value: 12.534454690626298.
# [I 2023-08-09 16:58:36,247] Trial 93 finished with value: 12.533047460664628 and parameters: {'subsample_for_bin': 131673, 'n_estimators': 4510, 'max_depth': 6, 'learning_rate': 0.054834260577325884, 'num_leaves': 47, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 16}. Best is trial 93 with value: 12.533047460664628.
# [I 2023-08-09 16:59:18,331] Trial 94 finished with value: 12.537393523821807 and parameters: {'subsample_for_bin': 122882, 'n_estimators': 4687, 'max_depth': 6, 'learning_rate': 0.05337881441549043, 'num_leaves': 48, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 17}. Best is trial 93 with value: 12.533047460664628.

# %%
from catboost import CatBoostRegressor
import optuna



def objective(trial):
    param = {}
    param['learning_rate'] = trial.suggest_float("learning_rate", 1e-6, 1e-1, log=True)
    param['depth'] = trial.suggest_int('depth', 9, 15)
    param['l2_leaf_reg'] = trial.suggest_float("l2_leaf_reg", 0., 1.0, step=0.1)
    param['min_child_samples'] = trial.suggest_categorical('min_child_samples', [1, 4, 8, 16, 32])
    param['grow_policy'] = 'Depthwise'
    param['iterations'] = trial.suggest_int("iterations", 1000, 5000)
    param['loss_function'] = 'RMSE'

    param['random_state'] = trial.suggest_int("random_state", 20, 50, step=2)
    param['logging_level'] = 'Silent'
    
    model = CatBoostRegressor(**param)

    model.fit(x_train, y_train)
    
    y_hat = model.predict(x_test)
    
    return mean_squared_error(y_test, y_hat, squared=True)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

# %%
def xgb_1(no):
  param_1 = {'n_estimators': 2552, 'max_depth': 9, 'learning_rate': 0.010419707354527082, 'gamma': 0.30000000000000004, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.30000000000000004, 'reg_lambda': 0.5, 'random_state': 28}

  param_2 = {'n_estimators': 4627, 'max_depth': 10, 
             'learning_rate': 0.03031698197768738, 
             'gamma': 0.7000000000000001, 'min_child_weight': 7, 
             'subsample': 0.9, 'colsample_bytree': 1.0, 
             'reg_alpha': 0.30000000000000004, 
             'reg_lambda': 0.30000000000000004, 
             'random_state': 22, 'grow_policy' : 'depthwise', 
            'n_jobs' : -1}
  
  params = [param_1, param_2]
  xgb = xgboost.XGBRegressor(**params[no])
  return xgb

def lgbm_1(no):
  param_1 = {'subsample_for_bin': 131673, 'n_estimators': 4510, 'max_depth': 6, 'learning_rate': 0.054834260577325884, 'num_leaves': 47, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 16}

  param_2 = {'subsample_for_bin': 155546, 'n_estimators': 3768, 'max_depth': 7, 'learning_rate': 0.04067420520019853, 'num_leaves': 50, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 16}
  
  param_3 = {'subsample_for_bin': 122882, 'n_estimators': 4687, 'max_depth': 6, 'learning_rate': 0.05337881441549043, 'num_leaves': 48, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.7000000000000001, 'reg_lambda': 0.30000000000000004, 'random_state': 34, 'min_child_samples': 17}
  
  params = [param_1, param_2, param_3]
  lgbm = lgb.LGBMRegressor(**params[no])
  return lgbm

# %%
from sklearn.linear_model import Ridge

lin = Ridge(random_state=42)
lin.fit(x_train, y_train)
pred = lin.predict(x_test)
print(f'test_data: {smape(y_test, pred)}')
# Out:
# test_data: 16.651594

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import LinearRegression


estimators1 = [('xgb_1{}'.format(i), xgb_1(i)) for i in range(1)]
estimators2 = [('lgbm_1{}'.format(j), lgbm_1(j))  for j in range(2)]
estimators = estimators1+estimators2

model = StackingRegressor(estimators=estimators, cv=3, final_estimator=Ridge(random_state=42), n_jobs = -1, verbose=1, passthrough=False)

# %%
model.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.7min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.3min finished
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 11.5min finished
# StackingRegressor(cv=3,
#                   estimators=[('xgb_10',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.9,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             gamma=0.30000000000000004,
#                                             gpu_id=None, grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constr...
#                                              reg_lambda=0.30000000000000004,
#                                              subsample_for_bin=131673)),
#                               ('lgbm_11',
#                                LGBMRegressor(learning_rate=0.04067420520019853,
#                                              max_depth=7, min_child_samples=16,
#                                              min_child_weight=1,
#                                              n_estimators=3768, num_leaves=50,
#                                              random_state=34, reg_alpha=0.5,
#                                              reg_lambda=0.30000000000000004,
#                                              subsample=0.9,
#                                              subsample_for_bin=155546))],
#                   final_estimator=Ridge(random_state=42), n_jobs=-1, verbose=1)

# %%
import pickle
pickle.dump(model, open('stack_model_submission-2.pkl','wb'))

# %%
pred = model.predict(x_test)
print(f'test_data: {smape(y_test, pred)}')
plot_eval(pred, y_test)
# Out:
# test_data: 7.851232

# %%
pred = model.predict(x_train)
print(f'train_data: {smape(y_train, pred)}')
plot_eval(pred, y_train)
# Out:
# train_data: 7.542712

# %%
df_test = pd.read_csv('new_test.csv')
df_test.head()
# Out:
#    id             waktu_setempat   id_jalan  id_titik_mulai  id_titik_akhir  \
# 0   0  2020-02-23 00:00:00+00:00    4004732        32046542      6454026544
# 1   1  2020-02-23 00:00:00+00:00  182210371      1314925464      1314925496
# 2   2  2020-02-23 00:00:00+00:00   22932408      1482086782        26481020
# 3   3  2020-02-23 00:00:00+00:00  182210371         3892883       267337489
# 4   4  2020-02-23 00:00:00+00:00   66924592       266041030      2592978110
#
#    lanes  lanes:forward  lit maxspeed  mulai_lat  mulai_lon  akhir_lat  \
# 0    2.0            NaN  yes   30 mph  51.465182  -0.255240  51.465204
# 1    NaN            2.0  yes   30 mph  51.458973  -0.141882  51.459254
# 2    NaN            NaN  yes   20 mph  51.449437  -0.160688  51.449295
# 3    NaN            2.0  yes   30 mph  51.457325  -0.143228  51.457466
# 4    NaN            NaN  yes   30 mph  51.467314  -0.112842  51.466309
#
#    akhir_lon  distance
# 0  -0.254595    0.0311
# 1  -0.141646    0.0416
# 2  -0.161060    0.0155
# 3  -0.143110    0.0155
# 4  -0.113371    0.0889

# %%
df_test = prepare_data(df_test)
df_test.head()
# Out:
# Convert to kph: 100%|██████████| 127489/127489 [00:00<00:00, 5108163.11it/s]
# time categorization: 100%|██████████| 127489/127489 [00:09<00:00, 13428.45it/s]
#    id   id_jalan  id_titik_mulai  id_titik_akhir  maxspeed  mulai_lat  \
# 0   0    4004732        32046542      6454026544   48.2803  51.465182
# 1   1  182210371      1314925464      1314925496   48.2803  51.458973
# 2   2   22932408      1482086782        26481020   32.1869  51.449437
# 3   3  182210371         3892883       267337489   48.2803  51.457325
# 4   4   66924592       266041030      2592978110   48.2803  51.467314
#
#    mulai_lon  akhir_lat  akhir_lon  distance  is_weekend  hour        date  \
# 0  -0.255240  51.465204  -0.254595    0.0311           1     0  2020-02-23
# 1  -0.141882  51.459254  -0.141646    0.0416           1     0  2020-02-23
# 2  -0.160688  51.449295  -0.161060    0.0155           1     0  2020-02-23
# 3  -0.143228  51.457466  -0.143110    0.0155           1     0  2020-02-23
# 4  -0.112842  51.466309  -0.113371    0.0889           1     0  2020-02-23
#
#    is_night  is_rush_hour
# 0         0             1
# 1         0             1
# 2         0             1
# 3         0             1
# 4         0             1

# %%
data_test = df_test.drop(['id', 'id_jalan', 'id_titik_mulai', 'id_titik_akhir', 'date'], axis=1)
pred_test = model.predict(data_test)

# %%
subm = pd.read_csv('submissionV2.csv')
subm.head()
# Out:
#    id  rerata_kecepatan
# 0   0         41.504017
# 1   1         41.519714
# 2   2         34.982294
# 3   3         40.739993
# 4   4         32.622729

# %%
subm['rerata_kecepatan'] = pred_test
subm.head()
# Out:
#    id  rerata_kecepatan
# 0   0         43.013100
# 1   1         39.157854
# 2   2         36.455321
# 3   3         43.624972
# 4   4         30.233755

# %%
subm.to_csv('submission-new_data-v1.csv', index=False)
